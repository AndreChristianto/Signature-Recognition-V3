# %% [markdown]
# # Triplet Loss

# %% [markdown]
# ### Load VGG16 Model

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
import cv2 as cv
import numpy as np
import os
# Out:
# WARNING:tensorflow:From C:\Users\Andreas Christianto\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
size = 64

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(size, size, 3))
gap = GlobalAveragePooling2D()(base_model.output)
model = Model(inputs=base_model.input, outputs=gap)

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Andreas Christianto\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Christianto\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 70, 70, 3)            0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 32, 32, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 32, 32, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 32, 32, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 34, 34, 64)           0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 16, 16, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 16, 16, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 16, 16, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 16, 16, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 16, 16, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 16, 16, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 16, 16, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 16, 16, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 16, 16, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 16, 16, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 16, 16, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 16, 16, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 16, 16, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 16, 16, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 16, 16, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 16, 16, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 16, 16, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 16, 16, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 8, 8, 128)            32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 8, 8, 128)            147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 8, 8, 512)            131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 8, 8, 512)            0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 8, 8, 512)            0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 8, 8, 128)            65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 8, 8, 128)            147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 8, 8, 512)            0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 8, 8, 512)            0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 8, 8, 128)            65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 8, 8, 128)            147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 8, 8, 512)            0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 8, 8, 512)            0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 8, 8, 128)            65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 8, 8, 128)            147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 8, 8, 512)            66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 8, 8, 512)            2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 8, 8, 512)            0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 8, 8, 512)            0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 4, 4, 256)            131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 4, 4, 256)            590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 4, 4, 1024)           525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 4, 4, 1024)           4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 4, 4, 1024)           4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 4, 4, 1024)           0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 4, 4, 1024)           0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 4, 4, 256)            262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 4, 4, 256)            590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 4, 4, 1024)           4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 4, 4, 1024)           0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 4, 4, 1024)           0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 4, 4, 256)            262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 4, 4, 256)            590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 4, 4, 1024)           4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 4, 4, 1024)           0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 4, 4, 1024)           0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 4, 4, 256)            262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 4, 4, 256)            590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 4, 4, 1024)           4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 4, 4, 1024)           0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 4, 4, 1024)           0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 4, 4, 256)            262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 4, 4, 256)            590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 4, 4, 1024)           4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 4, 4, 1024)           0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 4, 4, 1024)           0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 4, 4, 256)            262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 4, 4, 256)            590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 4, 4, 256)            1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 4, 4, 1024)           263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 4, 4, 1024)           4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 4, 4, 1024)           0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 4, 4, 1024)           0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 2, 2, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 2, 2, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 2, 2, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 2, 2, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 2, 2, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 2, 2, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 2, 2, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 2, 2, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 2, 2, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 2, 2, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 2, 2, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 2, 2, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 2, 2, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 2, 2, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 2, 2, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 2, 2, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 2, 2, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 2, 2, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 2, 2, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 2, 2, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 2, 2, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 2, 2, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#  GlobalAveragePooling2D)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Triplet Loss Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
def create_triplet_loss_model(embedding_model, input_shape):
    anchor_input = layers.Input(shape=input_shape, name='anchor_input')
    positive_input = layers.Input(shape=input_shape, name='positive_input')
    negative_input = layers.Input(shape=input_shape, name='negative_input')

    # Get embeddings
    anchor_embedding = embedding_model(anchor_input)
    positive_embedding = embedding_model(positive_input)
    negative_embedding = embedding_model(negative_input)

    # Triplet loss function
    margin = 0.5
    positive_distance = tf.reduce_sum(tf.square(anchor_embedding - positive_embedding), axis=1)
    negative_distance = tf.reduce_sum(tf.square(anchor_embedding - negative_embedding), axis=1)
    loss = tf.maximum(0.0, positive_distance - negative_distance + margin)
    loss = tf.reduce_mean(loss)

    triplet_loss_model = models.Model(inputs=[anchor_input, positive_input, negative_input], outputs=loss)
    return triplet_loss_model

# %%
triplet_model = create_triplet_loss_model(model, input_shape=(size, size, 3))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
triplet_model.compile(optimizer=optimizer, loss='mean_squared_error')

# %%
triplet_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  anchor_input (InputLayer)   [(None, 64, 64, 3)]          0         []
#
#  positive_input (InputLayer  [(None, 64, 64, 3)]          0         []
#  )
#
#  negative_input (InputLayer  [(None, 64, 64, 3)]          0         []
#  )
#
#  model (Functional)          (None, 2048)                 2358771   ['anchor_input[0][0]',
#                                                           2          'positive_input[0][0]',
#                                                                      'negative_input[0][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 2048)                 0         ['model[0][0]',
#  da)                                                                 'model[1][0]']
#
#  tf.math.subtract_1 (TFOpLa  (None, 2048)                 0         ['model[0][0]',
#  mbda)                                                               'model[2][0]']
#
#  tf.math.square (TFOpLambda  (None, 2048)                 0         ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.square_1 (TFOpLamb  (None, 2048)                 0         ['tf.math.subtract_1[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLa  (None,)                      0         ['tf.math.square[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_1 (TFOp  (None,)                      0         ['tf.math.square_1[0][0]']
#  Lambda)
#
#  tf.math.subtract_2 (TFOpLa  (None,)                      0         ['tf.math.reduce_sum[0][0]',
#  mbda)                                                               'tf.math.reduce_sum_1[0][0]']
#
#  tf.__operators__.add (TFOp  (None,)                      0         ['tf.math.subtract_2[0][0]']
#  Lambda)
#
#  tf.math.maximum (TFOpLambd  (None,)                      0         ['tf.__operators__.add[0][0]']
#  a)
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.math.maximum[0][0]']
#  ambda)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Read Images and separate into anchors, positives, and negatives

# %%
train_folder = "../../template/ICDAR-data/train"
test_folder = "../../template/ICDAR-data/test"
validation_folder = "../../template/ICDAR-data/validation"

# %%
def read_images(folder_path):
    features = []
    names = []
    labels = []
    signatures = [folder for folder in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, folder))]

    for signature in signatures:
        signature_path = os.path.join(folder_path, signature)
        images = os.listdir(signature_path)

        batch_features = []
        batch_names = []
        batch_labels = []

        for image_name in images:
            image_path = os.path.join(signature_path, image_name)
            # Read dan pre-processing gambar
            img = cv.imread(image_path)
            img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            img = cv.resize(img, (size, size))
            img = np.array(preprocess_input(img))

            features.append(img)
            names.append(signature[:3])

            if signature.endswith("_forg"):
                labels.append(0)
            else:
                labels.append(1)
        
    features = np.array(features)
    names = np.array(names)
    labels = np.array(labels)
        
    return features, names, labels

# %%
train_features, train_names, train_labels = read_images(train_folder)

# %%
train_features_triplet_path = "../../template/ICDAR-RESNET-feature/train_features_triplet.npy"
train_names_triplet_path = "../../template/ICDAR-RESNET-feature/train_names_triplet.npy"
train_labels_triplet_path = "../../template/ICDAR-RESNET-feature/train_labels_triplet.npy"

# %%
np.save(train_features_triplet_path, train_features)
np.save(train_names_triplet_path, train_names)
np.save(train_labels_triplet_path, train_labels)

# %%
train_features = np.load(train_features_triplet_path)
train_names = np.load(train_names_triplet_path)
train_labels = np.load(train_labels_triplet_path)

# %%
print(train_features.shape)
print(train_names.shape)
print(train_labels.shape)
# Out:
# (857, 64, 64, 3)
# (857,)
# (857,)

# %%
unique_names = set(train_names)
sorted_names = sorted(unique_names)

# %%
print(sorted_names)
# Out:
# ['001', '002', '003', '004', '006', '009', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069']

# %%
def split_positive_negative(features, names, labels, sorted_names):
    anchors = []
    positives = []
    negatives = []
    
    for name in sorted_names:
        indices = np.where(names == name)[0]
        positive_set, negative_set = [], []

        for index in indices:
            # print(labels[index])
            if labels[index] == 0:
                negative_set.append(features[index])
            else:
                positive_set.append(features[index])

        negative_set = np.array(negative_set)
        positive_set = np.array(positive_set)

        anchor = positive_set[0]
        positive_set = positive_set[1:]

        anchor_set = []
        if(len(positive_set) < len(negative_set)):
            positive_idx = np.random.choice(len(positive_set), size=len(negative_set), replace=True)
            positive = positive_set[positive_idx]
            negative = negative_set
            for _ in range(0, len(negative_set)):
                anchor_set.append(anchor)
        elif(len(positive_set) > len(negative_set)):
            negative_idx = np.random.choice(len(negative_set), size=len(positive_set), replace=True)
            negative = negative_set[negative_idx]
            positive = positive_set
            for _ in range(0, len(positive_set)):
                anchor_set.append(anchor)
        else:
            positive = positive_set
            negative = negative_set
            for _ in range(0, len(negative_set)):
                anchor_set.append(anchor)

        anchors.append(anchor_set)
        positives.append(positive)
        negatives.append(negative)

    anchors = np.concatenate(anchors)
    positives = np.concatenate(positives)
    negatives = np.concatenate(negatives)

    return anchors, positives, negatives

# %%
train_anchors, train_positives, train_negatives = split_positive_negative(train_features, train_names, train_labels, sorted_names)

# %%
train_anchors_path = "../../template/ICDAR-RESNET-feature/train_anchors.npy"
train_positives_path = "../../template/ICDAR-RESNET-feature/train_positives.npy"
train_negatives_path = "../../template/ICDAR-RESNET-feature/train_negatives.npy"

# %%
np.save(train_anchors_path, train_anchors)
np.save(train_positives_path, train_positives)
np.save(train_negatives_path, train_negatives)

# %%
train_anchors = np.load(train_anchors_path)
train_positives = np.load(train_positives_path)
train_negatives = np.load(train_negatives_path)

# %%
print(train_anchors.shape)
print(train_positives.shape)
print(train_negatives.shape)
# Out:
# (472, 64, 64, 3)
# (472, 64, 64, 3)
# (472, 64, 64, 3)

# %%
history = triplet_model.fit([train_anchors, train_positives, train_negatives], np.zeros_like(train_anchors), epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\Andreas Christianto\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 15/15 [==============================] - 97s 3s/step - loss: 77295.2812
# Epoch 2/5
# 15/15 [==============================] - 40s 3s/step - loss: 27225.6777
# Epoch 3/5
# 15/15 [==============================] - 39s 3s/step - loss: 1409.0161
# Epoch 4/5
# 15/15 [==============================] - 40s 3s/step - loss: 517.6420
# Epoch 5/5
# 15/15 [==============================] - 40s 3s/step - loss: 513.5659

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Triplet Loss Over Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Feature Extraction

# %%
def extract_features(folder_path, batch_size=32):
    features = []
    names = []
    labels = []
    signatures = [folder for folder in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, folder))]

    for signature in signatures:
        signature_path = os.path.join(folder_path, signature)
        images = os.listdir(signature_path)

        batch_features = []
        batch_names = []
        batch_labels = []

        for image_name in images:
            image_path = os.path.join(signature_path, image_name)
            # Read dan pre-processing gambar
            img = cv.imread(image_path)
            img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            img = cv.resize(img, (size, size))
            img = np.array(preprocess_input(img))

            batch_features.append(img)
            batch_names.append(signature[:3])

            if signature.endswith("_forg"):
                batch_labels.append(0)
            else:
                batch_labels.append(1)

            if len(batch_features) == batch_size:
                batch_features = np.array(batch_features)
                batch_features = model.predict(batch_features)
                batch_features = batch_features.reshape(len(batch_features), -1)

                features.extend(batch_features)
                names.extend(batch_names)
                labels.extend(batch_labels)

                batch_features = []
                batch_names = []
                batch_labels = []

        if batch_features:
            batch_features = np.array(batch_features)
            batch_features = model.predict(batch_features)
            batch_features = batch_features.reshape(len(batch_features), -1)

            features.extend(batch_features)
            names.extend(batch_names)
            labels.extend(batch_labels)

    return features, names, labels

# %%
train_features_new, _, _ = extract_features(train_folder)
test_features, _, _ = extract_features(test_folder)
validation_features, _, _ = extract_features(validation_folder)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 150ms/step

# %%
print(len(train_features_new), len(train_features_new[0]))
print(len(test_features), len(test_features[0]))
print(len(validation_features), len(validation_features[0]))
# Out:
# 857 2048
# 401 2048
# 391 2048

# %%
print(train_features_new)
# Out:
# [array([0.        , 0.        , 0.        , ..., 2.175835  , 2.9235513 ,
#        0.05559845], dtype=float32), array([0.19483039, 0.8322164 , 0.        , ..., 1.055892  , 1.3340142 ,
#        0.        ], dtype=float32), array([1.3683283, 1.0246152, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.29138142, 0.        , 0.        , ..., 0.40090722, 1.813832  ,
#        0.02889659], dtype=float32), array([0.08709949, 0.2314812 , 0.        , ..., 0.485641  , 1.6897094 ,
#        0.05489196], dtype=float32), array([0.09024683, 0.        , 0.        , ..., 1.6526754 , 1.39796   ,
#        0.        ], dtype=float32), array([0.2535121 , 0.5935421 , 0.        , ..., 1.184858  , 1.1558871 ,
#        0.14125514], dtype=float32), array([0.15310884, 4.304707  , 0.        , ..., 0.        , 0.2913554 ,
#        0.        ], dtype=float32), array([0.42665356, 0.51353836, 0.        , ..., 0.97839177, 0.946371  ,
#        0.01020142], dtype=float32), array([1.1849234 , 0.52564263, 0.        , ..., 3.18064   , 3.4155934 ,
#        0.21697922], dtype=float32), array([2.1221306 , 0.09772351, 0.        , ..., 0.        , 1.4530928 ,
#        0.55785763], dtype=float32), array([0.30745402, 1.6462678 , 0.        , ..., 0.        , 1.687666  ,
#        0.25039786], dtype=float32), array([0.7423461 , 0.8097288 , 0.        , ..., 0.        , 0.89824945,
#        0.22107974], dtype=float32), array([0.06941371, 0.        , 0.        , ..., 0.16813058, 0.28074768,
#        0.04155441], dtype=float32), array([0.        , 0.        , 0.        , ..., 1.2362418 , 0.        ,
#        0.01742106], dtype=float32), array([0.        , 0.95103025, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.7497727 , 0.21447843, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.09982419, 2.4089699 , 0.        , ..., 1.2533863 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 3.375135  , 0.        , ..., 0.        , 0.        ,
#        0.13120377], dtype=float32), array([0.10792612, 0.        , 0.        , ..., 1.7068973 , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 1.1235821, 0.       ,
#        0.       ], dtype=float32), array([0.02030429, 0.        , 0.        , ..., 2.2591453 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.03831908, ..., 2.1616187 , 0.        ,
#        0.0710577 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.7465998, 0.       , 0.       , ..., 1.8711971, 0.       ,
#        0.       ], dtype=float32), array([0.98482925, 0.        , 0.        , ..., 0.1317218 , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.1311414, 0.       ,
#        0.       ], dtype=float32), array([1.1273    , 0.        , 0.        , ..., 0.14298148, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.7035937, 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.25039712, 0.        ,
#        0.        ], dtype=float32), array([1.5898376, 0.       , 0.       , ..., 0.0772738, 0.       ,
#        0.       ], dtype=float32), array([0.9014404 , 1.3847368 , 0.        , ..., 0.13689116, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.5330822 , 0.        , ..., 0.        , 0.        ,
#        0.31804636], dtype=float32), array([1.0907345, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([1.0756961 , 0.2807853 , 0.        , ..., 0.        , 0.        ,
#        0.89559805], dtype=float32), array([1.5405629 , 0.17095658, 0.        , ..., 0.30185112, 0.        ,
#        0.        ], dtype=float32), array([6.1266313, 0.       , 0.       , ..., 0.7038955, 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.12243894, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 0.      , 2.197617],
#       dtype=float32), array([0.        , 0.03003785, 0.        , ..., 0.05165685, 0.        ,
#        0.        ], dtype=float32), array([0.09214327, 0.        , 0.        , ..., 0.        , 0.9490754 ,
#        0.        ], dtype=float32), array([0.0252787 , 0.60094565, 0.        , ..., 0.        , 0.        ,
#        2.0119958 ], dtype=float32), array([5.0236261e-04, 7.7197266e-01, 0.0000000e+00, ..., 0.0000000e+00,
#        0.0000000e+00, 3.6792719e-01], dtype=float32), array([0.       , 0.5680803, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.      , 2.551725, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.       , 0.6931852, 0.       , ..., 0.       , 0.       ,
#        0.9810433], dtype=float32), array([0.09936886, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.74210924], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.4371852, 0.       , ..., 0.       , 0.       ,
#        1.8058975], dtype=float32), array([0.        , 0.01064709, 0.        , ..., 0.        , 0.        ,
#        0.01120967], dtype=float32), array([0.6554158, 0.       , 0.       , ..., 1.5685124, 0.       ,
#        0.       ], dtype=float32), array([0.23691213, 1.7923574 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.25479138, 0.        , 0.        , ..., 0.        , 0.2007416 ,
#        0.        ], dtype=float32), array([0.       , 1.2634056, 0.       , ..., 0.       , 0.       ,
#        0.2020464], dtype=float32), array([0.       , 0.3119918, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.17699347, 0.84027296, 0.        , ..., 0.        , 1.3625288 ,
#        0.        ], dtype=float32), array([0.        , 2.2128496 , 0.        , ..., 0.        , 1.0930187 ,
#        0.20785165], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.72517145, 2.2309484 , 0.        , ..., 0.        , 0.        ,
#        0.44094214], dtype=float32), array([1.0726744 , 2.9972157 , 0.        , ..., 0.25370497, 0.        ,
#        0.        ], dtype=float32), array([0.      , 4.311636, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.7911582, 0.       , 0.       , ..., 0.5364767, 2.5906556,
#        0.       ], dtype=float32), array([0.04962775, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.58376336, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.529892  , 0.        , ..., 0.72541034, 0.23549761,
#        0.11393537], dtype=float32), array([0.16569504, 0.23085499, 0.00281125, ..., 0.        , 0.04922826,
#        0.        ], dtype=float32), array([0.39627028, 3.9479017 , 0.        , ..., 0.08221987, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.4782639, 0.       , ..., 0.       , 1.2546066,
#        0.       ], dtype=float32), array([0.       , 1.4481028, 0.       , ..., 0.       , 5.572562 ,
#        0.       ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#        4.6009574], dtype=float32), array([0.        , 0.3248338 , 0.        , ..., 0.21938667, 0.        ,
#        4.355755  ], dtype=float32), array([0.        , 0.        , 2.288193  , ..., 0.30736127, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.28394753, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.4107663, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.32759863, 0.        ,
#        0.        ], dtype=float32), array([0.21882983, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.12018669, 0.        , ..., 1.0188828 , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 1.7761321 , 0.        , ..., 0.        , 0.        ,
#        0.06179136], dtype=float32), array([0.00680362, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.      , 0.241911, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 0.03503016, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.09464304,
#        0.        ], dtype=float32), array([0.       , 2.1670198, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.32263386, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.36386433, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.1858229, ..., 0.       , 0.       ,
#        2.4105978], dtype=float32), array([0.        , 0.13570762, 0.        , ..., 0.        , 0.        ,
#        1.3438323 ], dtype=float32), array([0.      , 0.      , 0.614381, ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.05612849, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.02994715, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.36586168], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.75849676, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.9941806, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 1.838998  , 0.        , ..., 0.17659235, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.7844603, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 0.3857941, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 4.9895945 , 0.03419441, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.13558576, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.4178505 , 0.        , ..., 0.        , 0.36301914,
#        0.        ], dtype=float32), array([0.      , 3.046029, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 0.90334976, 0.14384161, ..., 0.43104917, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.8343018, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 1.6480801, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.      , 3.208817, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 3.6618834 , 0.        , ..., 0.33568287, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.48774892, 0.        , ..., 0.2551214 , 0.        ,
#        0.        ], dtype=float32), array([0.      , 0.085141, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 1.1258608, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.01129152, 3.498087  , 0.        , ..., 0.        , 0.04679834,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.9450072 , 0.        ,
#        0.11917725], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.05853934, 0.        ,
#        0.06620622], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.20044655, 0.        , 0.        , ..., 2.283787  , 0.        ,
#        1.8875936 ], dtype=float32), array([0.        , 2.169801  , 0.        , ..., 0.        , 0.        ,
#        0.32912016], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.08364762, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.09156334, 0.        ,
#        0.        ], dtype=float32), array([0.6370537, 0.       , 0.       , ..., 2.7564006, 0.       ,
#        1.7646992], dtype=float32), array([0.        , 0.        , 0.56556034, ..., 0.35211998, 0.        ,
#        0.7449539 ], dtype=float32), array([0.        , 0.        , 0.93589973, ..., 0.38833272, 0.        ,
#        1.5662718 ], dtype=float32), array([0.        , 0.19471297, 0.        , ..., 0.76017123, 0.00594101,
#        0.09764665], dtype=float32), array([0.35817677, 0.        , 2.2740307 , ..., 0.33720595, 0.        ,
#        0.46922594], dtype=float32), array([0.44847953, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.04890911, 0.        ,
#        0.15534858], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.01812628, 0.41393128, 0.        , ..., 0.        , 0.15876323,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.57743186, 0.        , ..., 0.        , 0.        ,
#        6.80301   ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.02322763, 0.        ,
#        0.        ], dtype=float32), array([0.01655626, 0.09303005, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.00931856, 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.16521263, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.5045251, 0.       ,
#        0.       ], dtype=float32), array([0.        , 1.3497142 , 0.        , ..., 0.02488047, 0.        ,
#        0.        ], dtype=float32), array([0.25283283, 0.        , 0.        , ..., 0.9704879 , 0.        ,
#        0.7032559 ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.69122857, 0.36672717,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.11662371,
#        4.701458  ], dtype=float32), array([1.3369932, 2.0292897, 0.       , ..., 0.       , 0.7562417,
#        0.8201786], dtype=float32), array([0.51552665, 0.        , 0.        , ..., 0.11020085, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.5090909, 0.       , ..., 0.       , 0.       ,
#        1.2622151], dtype=float32), array([0.19049321, 0.        , 0.        , ..., 0.65277225, 0.8560297 ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.66469085, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.24979883, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.25018907, 0.        , ..., 0.03805553, 0.        ,
#        0.        ], dtype=float32), array([1.0373311 , 0.        , 0.        , ..., 0.43309686, 0.16861415,
#        0.        ], dtype=float32), array([0.12877014, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.5943856 , 0.20990616, 0.31560075, ..., 0.10435484, 0.07532931,
#        0.        ], dtype=float32), array([2.0167143 , 0.        , 0.31317544, ..., 0.        , 0.01684002,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.01121924, 0.43386522,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.09465629, 0.34054583,
#        0.        ], dtype=float32), array([0.        , 0.02508677, 0.28897017, ..., 0.        , 0.19583145,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.31178123, 0.2170519 ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.45475847, ..., 0.5766683 , 1.0272036 ,
#        0.        ], dtype=float32), array([1.4366148, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#        0.23110887], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.32875565,
#        0.307707  ], dtype=float32), array([0.        , 0.28029677, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.0309874 , 0.1665379 , 0.        , ..., 0.        , 0.20314328,
#        0.44838253], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.08703688, 0.00241097, 0.        , ..., 0.01124913, 0.34954768,
#        0.        ], dtype=float32), array([0.        , 1.909649  , 0.10902596, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.767591  , 0.        , 0.27580997, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.82376873, ..., 0.        , 0.83389586,
#        0.        ], dtype=float32), array([0.46200782, 0.        , 0.        , ..., 0.17416772, 0.        ,
#        0.        ], dtype=float32), array([0.3808304 , 0.        , 0.        , ..., 0.07715452, 0.        ,
#        0.05355611], dtype=float32), array([1.6603423 , 0.40473127, 0.        , ..., 0.        , 0.        ,
#        0.02581489], dtype=float32), array([1.0228817, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.8069304, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.12747565, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.4603938, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([3.115897  , 0.        , 0.        , ..., 0.01305723, 0.        ,
#        0.        ], dtype=float32), array([0.5414709 , 0.39585117, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.47417, 0.     , 0.     , ..., 0.     , 0.     , 0.     ],
#       dtype=float32), array([0.8855039 , 0.14893393, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.248362  , 0.        , 0.        , ..., 0.        , 0.11622991,
#        0.        ], dtype=float32), array([0.12292645, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.48800895, 0.6507939 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.8394582 , 0.6969989 , 0.        , ..., 0.18736555, 0.        ,
#        0.        ], dtype=float32), array([0.06650218, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.00942536, 0.        , ..., 0.46593964, 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.8475809, 0.7113532, 0.       , ..., 0.       , 1.4642146,
#        0.       ], dtype=float32), array([0.6432365 , 0.        , 0.46495682, ..., 0.        , 0.3671983 ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 1.3105949,
#        0.       ], dtype=float32), array([0.        , 0.02402434, 0.        , ..., 0.        , 0.05174419,
#        0.        ], dtype=float32), array([0.        , 0.45074657, 0.        , ..., 0.        , 0.51831686,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 1.7582586,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.06862235, ..., 0.        , 0.39953166,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.04214984, 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.9296927 , 0.        , ..., 0.        , 0.13307375,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 1.2166715, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.8190759 , 0.        , ..., 0.21893835, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.05096221, 0.        , ..., 0.35978976, 1.1924005 ,
#        0.        ], dtype=float32), array([0.       , 1.0781155, 0.       , ..., 0.7385498, 0.640908 ,
#        0.       ], dtype=float32), array([0.       , 2.235977 , 0.       , ..., 0.       , 0.       ,
#        2.3632245], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.35966754, 0.        ,
#        0.96078527], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.36828142,
#        0.        ], dtype=float32), array([0.        , 0.40526813, 0.        , ..., 0.27397865, 0.20792261,
#        0.        ], dtype=float32), array([0.15471035, 0.        , 0.        , ..., 0.        , 0.36879334,
#        0.        ], dtype=float32), array([0.17705834, 0.06748593, 0.4204769 , ..., 0.24736494, 0.        ,
#        0.        ], dtype=float32), array([0.2861411, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#        0.00106847], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.19300759, 0.05953994, 0.15010083, ..., 0.15910473, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.91252077, 0.        ,
#        0.        ], dtype=float32), array([1.9516392, 0.       , 0.       , ..., 2.600926 , 0.       ,
#        0.       ], dtype=float32), array([0.33518243, 0.44684866, 0.        , ..., 0.3210178 , 0.        ,
#        0.        ], dtype=float32), array([0.17373005, 0.36676595, 1.1162153 , ..., 0.29815596, 0.        ,
#        0.6426594 ], dtype=float32), array([0.7784559 , 0.0387339 , 0.        , ..., 0.21876141, 0.        ,
#        0.        ], dtype=float32), array([0.03978248, 0.        , 0.        , ..., 0.06393914, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.6208858,
#        0.       ], dtype=float32), array([0.93404907, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.32367167, 0.        , 0.        , ..., 0.24840656, 0.72440076,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.01244701, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.47679487, 0.        , 0.        , ..., 0.        , 0.11570022,
#        1.1637509 ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 0.      , 0.012575],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.20069247, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.04142198, 0.        , ..., 0.00904888, 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.36802512, 0.        , 0.        , ..., 0.91147786, 0.08053184,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#        0.7947246], dtype=float32), array([0.        , 0.09084959, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.08640414, ..., 0.33397985, 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.9899116 , 0.        , 0.        , ..., 0.6054347 , 0.02558012,
#        0.        ], dtype=float32), array([1.3084816, 0.       , 0.       , ..., 3.2330258, 0.       ,
#        1.374405 ], dtype=float32), array([1.8384072, 0.       , 0.       , ..., 1.0346756, 0.       ,
#        0.4377385], dtype=float32), array([0.18636662, 0.        , 0.        , ..., 1.6618539 , 0.        ,
#        1.193498  ], dtype=float32), array([1.1872164, 0.       , 0.       , ..., 1.0057821, 0.       ,
#        1.1795568], dtype=float32), array([1.2228522, 0.       , 0.       , ..., 1.7174808, 0.       ,
#        1.6216592], dtype=float32), array([2.8008025 , 0.        , 0.        , ..., 0.50343585, 0.        ,
#        0.4208538 ], dtype=float32), array([0.05546655, 0.        , 0.        , ..., 0.9471812 , 0.        ,
#        2.4610288 ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.12986314, 0.06724357,
#        0.        ], dtype=float32), array([0.8509954 , 0.        , 0.        , ..., 0.        , 0.04775257,
#        0.04967871], dtype=float32), array([0.3008337 , 0.        , 0.        , ..., 0.26259524, 1.4687564 ,
#        2.3608642 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.39583808, 1.8201451 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.0108147, 0.9478282, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.07604925, 0.2547751 , 0.55167454, ..., 0.        , 0.02385519,
#        0.        ], dtype=float32), array([0.63924706, 0.40078178, 0.3155736 , ..., 0.74457276, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.8225647 , 0.23594321, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.056707  , 0.        , ..., 0.        , 0.        ,
#        0.64506114], dtype=float32), array([0.24006517, 3.305063  , 0.        , ..., 0.07735419, 0.49533018,
#        0.85231113], dtype=float32), array([0.02183137, 0.2594666 , 0.        , ..., 0.53695065, 0.        ,
#        1.3080972 ], dtype=float32), array([0.        , 0.18073478, 0.        , ..., 0.        , 1.2458868 ,
#        0.40770847], dtype=float32), array([0.64959157, 0.05461019, 0.05089566, ..., 0.        , 0.        ,
#        0.3193898 ], dtype=float32), array([0.       , 5.758029 , 0.       , ..., 0.       , 0.       ,
#        5.8783646], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.13613439, 2.9082477 , 0.        , ..., 0.        , 0.        ,
#        1.0035421 ], dtype=float32), array([0.        , 1.5068505 , 0.27024707, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 2.0155056, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.1448134 , 6.6688824 , 0.55495334, ..., 0.        , 0.        ,
#        0.80105674], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.3843156,
#        0.       ], dtype=float32), array([0.        , 0.18857962, 0.18219084, ..., 0.        , 0.24208695,
#        0.        ], dtype=float32), array([1.3654788, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([7.2807274 , 0.        , 0.        , ..., 0.15444654, 0.        ,
#        1.9524863 ], dtype=float32), array([0.        , 0.18383981, 0.        , ..., 0.16965625, 0.        ,
#        0.68691957], dtype=float32), array([1.9821607 , 0.        , 0.        , ..., 0.02359341, 0.        ,
#        0.        ], dtype=float32), array([1.949538 , 0.       , 0.       , ..., 0.       , 0.       ,
#        1.5172426], dtype=float32), array([5.4525523, 0.       , 0.       , ..., 0.       , 0.       ,
#        1.9232061], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.12903515, 0.        ,
#        0.        ], dtype=float32), array([2.2742422, 0.       , 0.4949577, ..., 0.543718 , 0.       ,
#        0.       ], dtype=float32), array([2.1591022, 2.7395258, 0.       , ..., 0.       , 0.       ,
#        1.1491351], dtype=float32), array([0.51487744, 0.03440933, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([5.3631244 , 0.        , 0.        , ..., 0.16837922, 0.        ,
#        0.3598104 ], dtype=float32), array([0.16681042, 4.140486  , 0.        , ..., 1.2379227 , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.5216329, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.09312043, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#        0.18266436], dtype=float32), array([0.31438956, 2.0674958 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.6363068, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.70499384,
#        0.        ], dtype=float32), array([2.424159, 0.      , 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([1.2239575 , 0.        , 0.09656867, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.54670244, 1.0958538 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.10697895, 0.28000143, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.03201599, 0.00295469, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.08342555, 0.        , 0.        , ..., 0.13153562, 0.        ,
#        0.        ], dtype=float32), array([0.       , 4.1121287, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.42366427, 3.324624  , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([5.419858, 0.      , 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.23539324, 0.        , 0.        , ..., 0.        , 0.04999235,
#        0.        ], dtype=float32), array([6.699921, 0.      , 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 0.        , 0.        , ..., 0.11305802, 0.24722531,
#        0.        ], dtype=float32), array([1.8248186, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.04600539,
#        0.        ], dtype=float32), array([0.        , 0.02931094, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.22209424, 0.03348184, 0.        , ..., 0.        , 0.6071172 ,
#        0.        ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 2.742855, 0.      ],
#       dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.52600014,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.24694608, 0.        ,
#        0.        ], dtype=float32), array([0.17838103, 0.        , 0.        , ..., 2.192428  , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.46781808, 0.        ,
#        0.        ], dtype=float32), array([0.14912711, 0.87320435, 0.        , ..., 1.1480225 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.283718  , ..., 0.        , 0.11853236,
#        0.        ], dtype=float32), array([0.        , 0.23632035, 0.        , ..., 0.02038786, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.4174484 , 0.        , ..., 0.11298287, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.04628663, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 3.1593785 , ..., 0.5637916 , 0.27002466,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 1.5031155, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 5.9843802 , 0.30194104, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 1.2684827, 0.       , ..., 0.       , 1.0537021,
#        0.       ], dtype=float32), array([0.        , 0.44544768, 0.        , ..., 1.2464029 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.6419767 , 0.81453836, ..., 0.86580884, 0.        ,
#        0.13638476], dtype=float32), array([0.       , 0.8122225, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.18105045, 1.6721042 , 0.        , ..., 0.525047  , 0.0405724 ,
#        0.        ], dtype=float32), array([0.        , 3.2183504 , 0.        , ..., 2.285999  , 0.        ,
#        0.11047258], dtype=float32), array([0.        , 2.5712929 , 0.91043425, ..., 1.2571965 , 0.        ,
#        0.        ], dtype=float32), array([1.0936916 , 0.77115834, 0.13175501, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.71792847, 0.        , ..., 0.22154742, 0.18078482,
#        0.29286486], dtype=float32), array([0.07490049, 0.84076965, 0.        , ..., 0.0138762 , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([2.7782932e-02, 3.8910909e+00, 1.7471118e-03, ..., 1.5940657e-01,
#        0.0000000e+00, 0.0000000e+00], dtype=float32), array([0.        , 0.        , 0.05038857, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.90426654, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.3202416, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 0.3036525, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.50311524, 0.        , ..., 0.02494147, 0.        ,
#        0.        ], dtype=float32), array([0.06989015, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 1.0107915, 0.       ,
#        0.       ], dtype=float32), array([0.       , 0.9509329, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 2.3675191, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.05274293, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.0891627 , 1.3639754 , 0.        , ..., 0.35340095, 0.        ,
#        0.        ], dtype=float32), array([0.      , 1.048616, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 0.44375968, 0.        , ..., 0.24022695, 0.32484412,
#        0.        ], dtype=float32), array([0.        , 1.264647  , 0.07731625, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.39710873, 1.6204183 ,
#        0.        ], dtype=float32), array([0.       , 0.4281744, 0.       , ..., 1.0958552, 0.       ,
#        0.       ], dtype=float32), array([1.2937791 , 0.        , 0.        , ..., 1.1794486 , 0.24982232,
#        0.        ], dtype=float32), array([0.71985173, 0.40090668, 0.        , ..., 0.        , 0.25097466,
#        0.        ], dtype=float32), array([2.392401  , 0.        , 0.        , ..., 0.40084642, 0.        ,
#        0.6833358 ], dtype=float32), array([0.91327, 0.     , 0.     , ..., 0.     , 0.     , 0.     ],
#       dtype=float32), array([0.       , 1.5497355, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.01863486, 0.21381654, 0.        , ..., 0.02871831, 0.        ,
#        0.        ], dtype=float32), array([0.20341933, 0.66746855, 0.        , ..., 0.7830589 , 0.        ,
#        0.04493253], dtype=float32), array([0.71443874, 0.59356374, 0.        , ..., 1.019218  , 0.        ,
#        0.        ], dtype=float32), array([0.15991378, 1.8327296 , 0.        , ..., 0.09872252, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.7319157, 0.       , ..., 1.4023473, 0.       ,
#        0.       ], dtype=float32), array([0.40085527, 0.34988254, 0.        , ..., 0.89966995, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.38766938, 1.5415176 , ..., 1.5147115 , 0.        ,
#        0.        ], dtype=float32), array([0.       , 2.9153876, 0.       , ..., 0.4177425, 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.48397723, 0.0736564 , ..., 1.2908554 , 0.        ,
#        0.        ], dtype=float32), array([0.7980636, 1.3434055, 0.       , ..., 0.       , 0.       ,
#        0.0243207], dtype=float32), array([1.120155  , 2.7141356 , 0.        , ..., 0.19439375, 0.        ,
#        0.0883438 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.01854257, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 1.5207434, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.81144845, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.044581  , 0.11673368, ..., 1.5658164 , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.9172473, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([1.1455014 , 0.11561493, 0.        , ..., 0.        , 0.09936098,
#        0.        ], dtype=float32), array([2.8873658, 4.901373 , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.969062  , 0.        , ..., 0.        , 0.61326164,
#        0.24025446], dtype=float32), array([0.      , 3.423512, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.897862 , 0.       , 1.276478 , ..., 0.7752496, 0.       ,
#        0.       ], dtype=float32), array([0.      , 3.363285, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 0.24960041, 0.10662049, ..., 0.        , 0.        ,
#        0.10308221], dtype=float32), array([0.        , 0.15578364, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 1.1986129, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.2193822 , 0.        ,
#        0.48788548], dtype=float32), array([0.       , 0.061226 , 0.       , ..., 0.1122961, 0.       ,
#        0.       ], dtype=float32), array([0.17380695, 0.4700754 , 0.        , ..., 0.18833941, 0.40793413,
#        0.        ], dtype=float32), array([1.6267445 , 0.30320257, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.19188103, 0.02984542, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.00760812, 0.3455084 , ..., 0.67335063, 0.11116676,
#        0.        ], dtype=float32), array([0.32644928, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.86852044, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.92918974, 0.25974506, 0.        , ..., 0.05956087, 0.        ,
#        0.        ], dtype=float32), array([0.89293844, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.6664089 , 0.24929528, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 3.0678096 , 0.        , ..., 0.09771875, 0.        ,
#        0.26338398], dtype=float32), array([0.        , 0.39949673, 0.        , ..., 0.6612035 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.31198725,
#        0.        ], dtype=float32), array([0.02205277, 0.        , 0.        , ..., 0.3099915 , 0.39400867,
#        0.        ], dtype=float32), array([0.12334976, 0.        , 0.        , ..., 1.0884407 , 0.4513666 ,
#        0.        ], dtype=float32), array([0.17728153, 0.        , 1.0387815 , ..., 0.        , 1.4136034 ,
#        0.        ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 7.203163, 0.      ],
#       dtype=float32), array([0.        , 0.        , 0.        , ..., 0.41081578, 0.25949618,
#        0.08528817], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.3215366,
#        0.       ], dtype=float32), array([0.     , 0.     , 0.     , ..., 0.     , 3.07847, 0.     ],
#       dtype=float32), array([0.        , 0.20424096, 0.18715262, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.1881125 , 0.        , ..., 0.        , 0.24199414,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.05631104, 0.        , 0.        , ..., 0.        , 0.22705486,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.03673558, 0.        , 0.        , ..., 0.        , 0.07762614,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 6.5071135,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.48042786,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.12716548,
#        0.        ], dtype=float32), array([0.        , 0.05761491, 0.        , ..., 0.        , 0.7012097 ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#        0.64930475], dtype=float32), array([0.        , 0.48845643, 0.        , ..., 0.        , 0.        ,
#        0.99783057], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#        0.75103706], dtype=float32), array([0.        , 0.14753065, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.18374023, 0.08010428, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.0071211,
#        0.       ], dtype=float32), array([0.        , 1.5280595 , 0.        , ..., 0.        , 0.01831471,
#        0.28437397], dtype=float32), array([0.        , 0.5793655 , 0.        , ..., 0.        , 0.18534344,
#        0.28490046], dtype=float32), array([0.54196864, 0.09235066, 0.        , ..., 1.2857997 , 0.        ,
#        0.8070078 ], dtype=float32), array([0.        , 1.3871253 , 0.        , ..., 0.00401008, 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.1590275 , 0.        , ..., 0.        , 0.32385856,
#        0.2927518 ], dtype=float32), array([0.        , 1.8908634 , 0.05179825, ..., 1.0214112 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.6087747 , 0.19537759, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.6305141 , 0.05056572, ..., 0.1594935 , 0.        ,
#        0.        ], dtype=float32), array([0.       , 1.2712945, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 4.6185427, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 1.0236636, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.09300274, 3.333081  , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.0081922, 0.       , ..., 0.       , 0.2683761,
#        0.       ], dtype=float32), array([0.        , 3.7892048 , 0.        , ..., 0.        , 0.        ,
#        0.00822344], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.36108536,
#        2.0921004 ], dtype=float32), array([0.       , 2.3400874, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 1.080978 ,
#        1.7718709], dtype=float32), array([0.83757246, 0.        , 0.        , ..., 0.1214949 , 1.1835748 ,
#        0.1969801 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.2459389 , 0.396903  ,
#        0.49785495], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.03643652, 0.20661132,
#        0.        ], dtype=float32), array([0.       , 1.4196869, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 1.105653, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.664663  , 0.05001117, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.72305006, 0.        , 0.10911492, ..., 0.        , 0.11846748,
#        0.        ], dtype=float32), array([0.27488494, 0.        , 0.        , ..., 0.        , 0.73265684,
#        0.        ], dtype=float32), array([0.      , 1.124057, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 0.06523696, 0.77879083, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.83581406, 2.1618104 , 0.60958266, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.2696612 , 0.        , ..., 0.        , 0.        ,
#        0.48143664], dtype=float32), array([0.        , 0.6506949 , 0.00858194, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.2839959, 1.255324 , 1.1629643, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 2.2487366 , 0.04414357, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.64669657, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.49212888, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.08967748, 0.        , 0.02078707, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.0292052 , 0.        , ..., 0.        , 0.24367112,
#        1.6015    ], dtype=float32), array([0.      , 0.      , 2.326795, ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 0.        , 0.00975721, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.3804365 , 0.        , 0.99214536, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.14796877, 0.153077  , 0.        , ..., 0.07855356, 0.        ,
#        0.        ], dtype=float32), array([0.1488501, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.72929686, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.7098252 , 0.74336076, ..., 0.        , 0.        ,
#        0.8414215 ], dtype=float32), array([0.       , 1.2877983, 0.       , ..., 0.       , 1.4558183,
#        0.       ], dtype=float32), array([0.        , 0.23763323, 0.        , ..., 0.        , 0.        ,
#        0.58924365], dtype=float32), array([0.        , 0.5140189 , 0.02138083, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.20010778, 0.        , 0.        , ..., 1.043229  , 0.        ,
#        1.9217528 ], dtype=float32), array([0.       , 0.1441825, 0.       , ..., 1.3072606, 0.       ,
# ...
#        0.        ], dtype=float32), array([0.05401087, 0.        , 0.14488232, ..., 0.00531343, 0.        ,
#        3.003024  ], dtype=float32), array([0.        , 0.53486264, 0.05151075, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.16365153,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 1.5998394, 0.       , ..., 0.       , 0.5250617,
#        0.       ], dtype=float32), array([0.        , 0.04103102, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.15554321, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.09666008,  0.9232821 ,  0.87254465, ...,  0.27327415,
#         0.        , 15.399917  ], dtype=float32), array([0.        , 0.        , 1.7443511 , ..., 0.02697146, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.14023888, 0.        , ..., 0.        , 0.7307973 ,
#        0.        ], dtype=float32), array([0.        , 0.21696019, 0.        , ..., 0.        , 0.32203466,
#        0.        ], dtype=float32), array([0.       , 0.6360185, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.03305572, 0.        , 0.        , ..., 0.7041448 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.01911896,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 1.2216612, 0.       ,
#        0.       ], dtype=float32), array([0.04286366, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.21431467, 0.02539172, 0.        , ..., 0.        , 0.        ,
#        0.8413857 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 2.0857751,
#        0.       ], dtype=float32), array([0.        , 0.08377925, 0.        , ..., 0.        , 0.73386526,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.97347057, 0.35662737, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.02847826, 5.539849  , 0.1197312 , ..., 0.04706347, 0.23304582,
#        5.2670355 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#        0.5313205], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.01246258, 0.        , 0.01896515, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.5474555 , 0.        , 0.        , ..., 0.15657458, 0.        ,
#        0.03667212], dtype=float32), array([0.20255113, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 3.5470011 , 0.        , ..., 0.        , 0.06385276,
#        0.24595393], dtype=float32), array([0.46857417, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.4378386, 1.7996788, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.01420035, 0.13798144, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 2.2270973, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.533065  , 0.08460782, ..., 0.14476503, 0.        ,
#        0.        ], dtype=float32), array([0.       , 1.4396571, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.34696972, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.21133438, 0.        , ..., 0.05393824, 0.        ,
#        0.        ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.232279, 0.      , 0.      ],
#       dtype=float32), array([0.       , 0.1574643, 0.019476 , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.0116318 , 0.34969246, 0.        , ..., 0.06631371, 0.        ,
#        2.175014  ], dtype=float32), array([2.6873603 , 0.30246055, 0.        , ..., 0.6274126 , 0.        ,
#        0.        ], dtype=float32), array([3.018958  , 0.        , 0.        , ..., 0.9184681 , 0.        ,
#        0.07501592], dtype=float32), array([1.6413515 , 0.        , 0.        , ..., 1.7605758 , 0.        ,
#        0.15043151], dtype=float32), array([1.5432688 , 1.3528366 , 0.        , ..., 0.53961307, 0.        ,
#        1.1049948 ], dtype=float32), array([0.7868267, 0.       , 0.       , ..., 0.0425618, 0.       ,
#        0.       ], dtype=float32), array([3.2914135 , 0.50438863, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.35107708, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.04446243], dtype=float32), array([0.        , 0.02168963, 0.        , ..., 0.07438898, 1.1233635 ,
#        2.512514  ], dtype=float32), array([0.32257724, 1.0068998 , 0.        , ..., 0.        , 0.02017049,
#        0.70256495], dtype=float32), array([0.        , 0.1273917 , 0.        , ..., 0.        , 0.30882233,
#        0.1138126 ], dtype=float32), array([0.21543223, 0.13855016, 0.        , ..., 0.25394833, 0.        ,
#        0.        ], dtype=float32), array([0.26731813, 0.11944371, 0.        , ..., 0.        , 0.07170115,
#        3.2435102 ], dtype=float32), array([0.        , 0.17485863, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.3173446, 1.2693197, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.25112173, 0.5502607 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.05387978, 0.68113863, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.85804343, 0.8976738 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.1047779 , 0.        , ..., 0.17913139, 0.        ,
#        0.02047078], dtype=float32), array([0.0521857, 1.5975521, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.04130495, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([2.7501667 , 0.54598457, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.03431513, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.09484018, 0.03716463, 0.        , ..., 0.5787846 , 0.        ,
#        0.13504103], dtype=float32), array([0.       , 1.4480648, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([2.986479  , 0.        , 0.        , ..., 0.04533005, 0.        ,
#        0.        ], dtype=float32), array([0.       , 1.2954013, 0.1925316, ..., 0.4165174, 0.       ,
#        0.       ], dtype=float32), array([0.69857514, 0.4324035 , 0.152574  , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.1002992 , 0.        , 0.        , ..., 0.00459251, 0.        ,
#        0.        ], dtype=float32), array([1.1206722 , 0.        , 0.        , ..., 0.47812814, 0.        ,
#        0.        ], dtype=float32), array([0.       , 1.1647303, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.09077477, 1.1496917 , 0.        , ..., 0.3050087 , 0.        ,
#        0.55493295], dtype=float32), array([0.        , 0.2864095 , 0.        , ..., 0.2653596 , 0.        ,
#        0.03861615], dtype=float32), array([0.837036  , 0.        , 0.        , ..., 0.19002897, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.51624167, 0.        , ..., 0.79567957, 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 2.2664092, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 1.3782872 , 0.17491722, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.2836167, 2.7088206, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 0.7060305, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 1.5081619, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.15184715, 0.        , 0.        , ..., 0.5740975 , 0.00761673,
#        0.        ], dtype=float32), array([0.07144149, 1.450702  , 0.        , ..., 0.        , 0.        ,
#        0.0600436 ], dtype=float32), array([0.        , 0.17251793, 0.        , ..., 3.9570322 , 0.8641405 ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.21167473, 0.        ,
#        0.6331381 ], dtype=float32), array([0.       , 1.236305 , 0.       , ..., 0.       , 0.6775826,
#        0.       ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 0.108886, 0.      ],
#       dtype=float32), array([0.28802088, 3.2536042 , 0.22292145, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.15017202, ..., 0.09188215, 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.7001522, 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.34088254, 0.        ,
#        0.        ], dtype=float32), array([0.08453202, 0.        , 0.        , ..., 0.09293447, 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.39767128, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.23816825, 0.        , 0.        , ..., 0.20256907, 0.        ,
#        1.4103909 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([1.9133037, 2.1948807, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.85893285, 0.        , ..., 0.4662721 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.24201778, 0.        , ..., 0.        , 0.        ,
#        0.1264663 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.08724413, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 6.817894  , 0.0400359 , ..., 0.        , 0.        ,
#        0.20843017], dtype=float32), array([0.61574703, 0.4679557 , 0.        , ..., 0.        , 0.        ,
#        2.2085795 ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.10346875, 0.5907905 , 0.        , ..., 0.41362262, 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.059533  , 0.63804257, ..., 1.1359811 , 0.        ,
#        0.        ], dtype=float32), array([0.      , 1.770804, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.       , 0.9677819, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 5.665217  , 0.05024953, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 4.7963386, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.4878977 , 4.061958  , 0.        , ..., 0.        , 0.09817272,
#        0.        ], dtype=float32), array([0.        , 2.2339597 , 0.07713222, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.42864606, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.06336821, 2.3761513 , 0.        , ..., 0.        , 0.        ,
#        1.2155077 ], dtype=float32), array([0.        , 2.6543388 , 0.18247806, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.7939331, 3.344072 , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.01116582, 0.09898598, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.4351263, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.55881643, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 4.0446815 , 0.17584541, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.      , 0.925668, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.08279687, 0.72978145, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.14757879, 0.        , 0.        , ..., 0.682912  , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.04974994, 0.        , ..., 0.        , 0.        ,
#        0.56515616], dtype=float32), array([0.        , 1.6891427 , 0.        , ..., 0.        , 0.        ,
#        0.30807328], dtype=float32), array([0.      , 1.179141, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0.        , 1.1088296 , 0.        , ..., 0.21005663, 0.58639836,
#        0.        ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 1.628196, 0.      ],
#       dtype=float32), array([0.00069083, 0.5132052 , 0.3025288 , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.6416125 , 0.14131023, ..., 0.        , 0.17758816,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.7736029,
#        0.       ], dtype=float32), array([0.        , 0.15092248, 0.        , ..., 0.        , 0.27066922,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.01814166, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.10388827, 0.829907  , 0.        , ..., 0.        , 0.16928767,
#        0.10237347], dtype=float32), array([0.07103696, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.3057673 ], dtype=float32), array([0.        , 0.21043739, 0.        , ..., 0.        , 0.96935904,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.48708037,
#        0.        ], dtype=float32), array([0.20087504, 0.00596169, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.        , 0.29148287,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.24894467, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.        , 0.        , 0.07333535, ..., 0.        , 0.        ,
#        1.4791522 ], dtype=float32), array([0.        , 0.        , 0.07890756, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 1.3534181, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.00674861, 0.16079707,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.3909664 , ..., 0.        , 0.91549546,
#        0.        ], dtype=float32)]

# %% [markdown]
# ### Save and Load Features, Names, and Labels to reduce time needed

# %%
train_features_path =  "../feature/ICDAR-RESNET-feature/train_features_triplet_loss.npy"
test_features_path = "../feature/ICDAR-RESNET-feature/test_features_triplet_loss.npy"
validation_features_path = "../feature/ICDAR-RESNET-feature/validation_features_triplet_loss.npy"

# %%
np.save(train_features_path, train_features_new)
np.save(validation_features_path, validation_features)
np.save(test_features_path, test_features)
